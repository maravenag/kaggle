# %% [markdown]
# ### Prepare the data
# +  Remove some columns
# +  Target encoding for categorical columns
# +  Fill NAs

# %%
import pandas as pd

# %%
data = pd.read_csv(filepath_or_buffer="data/train.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.drop(labels=["PassengerId","Name","Ticket","Cabin"], inplace=True, axis=1)

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
import category_encoders as ce

# %%
encoder = ce.TargetEncoder(cols=['Embarked','Sex'])

# %%
encoded = encoder.fit_transform(data,data['Survived'])

# %%
encoded.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0         0       3  22.0      1      0   7.2500           0         1
# 1         1       1  38.0      1      0  71.2833           1         0
# 2         1       3  26.0      0      0   7.9250           1         0
# 3         1       1  35.0      1      0  53.1000           1         0
# 4         0       3  35.0      0      0   8.0500           0         1
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           0           1
# 1           1           0           0
# 2           0           0           1
# 3           0           0           1
# 4           0           0           1

# %%
encoded['Age']=encoded.fillna(value=encoded['Age'].mean())

# %% [markdown]
# ### Using XGboost with bayesian optimization for hyperparams
# + Using BayesianOptimization

# %%
import xgboost as xgb
from bayes_opt import BayesianOptimization

# %%
xgboost_data = encoded

# %%
xgboost_data.head()
# Out:
#    Survived  Pclass  Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0         0       3  0.0      1      0   7.2500           0         1
# 1         1       1  1.0      1      0  71.2833           1         0
# 2         1       3  1.0      0      0   7.9250           1         0
# 3         1       1  1.0      1      0  53.1000           1         0
# 4         0       3  0.0      0      0   8.0500           0         1
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           0           1
# 1           1           0           0
# 2           0           0           1
# 3           0           0           1
# 4           0           0           1

# %%
y = xgboost_data['Survived']
x = xgboost_data.drop(['Survived'], axis=1)

# %%
xgtrain = xgb.DMatrix(x, label=y)

# %%
num_rounds = 100
random_state = 2018
num_iter = 25
init_points = 5
params = {'eta': 0.1,'silent': 1,'eval_metric': 'auc','verbose_eval': 0,'seed': random_state}

# %%
def run_xgboost(min_child_weight,
                 colsample_bytree,
                 max_depth,
                 subsample,
                 gamma,
                 alpha):

    params['min_child_weight'] = int(min_child_weight)
    params['cosample_bytree'] = max(min(colsample_bytree, 1), 0)
    params['max_depth'] = int(max_depth)
    params['subsample'] = max(min(subsample, 1), 0)
    params['gamma'] = max(gamma, 0)
    params['alpha'] = max(alpha, 0)

    cv_result = xgb.cv(params, xgtrain, num_boost_round=num_rounds, nfold=2,
             seed=random_state,
             callbacks=[xgb.callback.early_stop(50)])
    
    return cv_result['test-auc-mean'].values[-1]

# %%
val = run_xgboost(min_child_weight=5,colsample_bytree=0.8,max_depth=2,subsample=0.6,gamma=3,alpha=5)
print(val)
# Out:
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [0]	train-auc:1+0	test-auc:1+0
#
# 1.0

# %%
xgbBO = BayesianOptimization(run_xgboost, {'min_child_weight': (1, 20),
                                                'colsample_bytree': (0.1, 1),
                                                'max_depth': (5, 15),
                                                'subsample': (0.5, 1),
                                                'gamma': (0, 10),
                                                'alpha': (0, 10),
                                                })

xgbBO.maximize(init_points=init_points, n_iter=num_iter)
# Out:
# Initialization
# ---------------------------------------------------------------------------------------------------------------------------
#  Step |   Time |      Value |     alpha |   colsample_bytree |     gamma |   max_depth |   min_child_weight |   subsample |
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [0]	train-auc:1+0	test-auc:1+0
#
#     1 | 00m00s |    1.00000 |    5.4738 |             0.1973 |    5.7219 |     10.3322 |            12.3931 |      0.9180 |
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [0]	train-auc:1+0	test-auc:1+0
#
#     2 | 00m00s |    1.00000 |    5.2268 |             0.6346 |    8.0393 |      6.3071 |             6.2292 |      0.7178 |
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [0]	train-auc:1+0	test-auc:1+0
#
#     3 | 00m00s |    1.00000 |    4.4194 |             0.3601 |    2.0539 |     13.1529 |            10.8950 |      0.6992 |
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [0]	train-auc:1+0	test-auc:1+0
#
#     4 | 00m00s |    1.00000 |    7.5411 |             0.1215 |    0.4542 |      8.8007 |             4.0242 |      0.5633 |
# Multiple eval metrics have been passed: 'test-auc' will be used for early stopping.
#
# Will train until test-auc hasn't improved in 50 rounds.
# Stopping. Best iteration:
# [0]	train-auc:1+0	test-auc:1+0
#
#     5 | 00m00s |    1.00000 |    8.5075 |             0.3189 |    4.7723 |     14.8635 |            11.1012 |      0.9626 |
# /anaconda2/envs/spike_basico/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py:335: UserWarning: Predicted variances smaller than 0. Setting those variances to 0.
#   warnings.warn("Predicted variances smaller than 0. "
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-edcac1bf8e9d> in <module>()
#       7                                                 })
#       8
# ----> 9 xgbBO.maximize(init_points=init_points, n_iter=num_iter)
#
# /anaconda2/envs/spike_basico/lib/python3.6/site-packages/bayes_opt/bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, xi, **gp_params)
#     257                         bounds=self.space.bounds,
#     258                         random_state=self.random_state,
# --> 259                         **self._acqkw)
#     260
#     261         # Print new header
#
# /anaconda2/envs/spike_basico/lib/python3.6/site-packages/bayes_opt/helpers.py in acq_max(ac, gp, y_max, bounds, random_state, n_warmup, n_iter)
#      58                        x_try.reshape(1, -1),
#      59                        bounds=bounds,
# ---> 60                        method="L-BFGS-B")
#      61
#      62         # Store it if better than previous minimum(maximum).
#
# /anaconda2/envs/spike_basico/lib/python3.6/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     601     elif meth == 'l-bfgs-b':
#     602         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 603                                 callback=callback, **options)
#     604     elif meth == 'tnc':
#     605         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# /anaconda2/envs/spike_basico/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# /anaconda2/envs/spike_basico/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     279         def func_and_grad(x):
#     280             f = fun(x, *args)
# --> 281             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     282             return f, g
#     283     else:
#
# /anaconda2/envs/spike_basico/lib/python3.6/site-packages/scipy/optimize/optimize.py in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     661         ei[k] = 1.0
#     662         d = epsilon * ei
# --> 663         grad[k] = (f(*((xk + d,) + args)) - f0) / d[k]
#     664         ei[k] = 0.0
#     665     return grad
#
# /anaconda2/envs/spike_basico/lib/python3.6/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     291     def function_wrapper(*wrapper_args):
#     292         ncalls[0] += 1
# --> 293         return function(*(wrapper_args + args))
#     294
#     295     return ncalls, function_wrapper
#
# /anaconda2/envs/spike_basico/lib/python3.6/site-packages/bayes_opt/helpers.py in <lambda>(x)
#      55     for x_try in x_seeds:
#      56         # Find the minimum of minus the acquisition function
# ---> 57         res = minimize(lambda x: -ac(x.reshape(1, -1), gp=gp, y_max=y_max),
#      58                        x_try.reshape(1, -1),
#      59                        bounds=bounds,
#
# /anaconda2/envs/spike_basico/lib/python3.6/site-packages/bayes_opt/helpers.py in utility(self, x, gp, y_max)
#      93     def utility(self, x, gp, y_max):
#      94         if self.kind == 'ucb':
# ---> 95             return self._ucb(x, gp, self.kappa)
#      96         if self.kind == 'ei':
#      97             return self._ei(x, gp, y_max, self.xi)
#
# /anaconda2/envs/spike_basico/lib/python3.6/site-packages/bayes_opt/helpers.py in _ucb(x, gp, kappa)
#     101     @staticmethod
#     102     def _ucb(x, gp, kappa):
# --> 103         mean, std = gp.predict(x, return_std=True)
#     104         return mean + kappa * std
#     105
#
# /anaconda2/envs/spike_basico/lib/python3.6/site-packages/sklearn/gaussian_process/gpr.py in predict(self, X, return_std, return_cov)
#     313                 return y_mean
#     314         else:  # Predict based on GP posterior
# --> 315             K_trans = self.kernel_(X, self.X_train_)
#     316             y_mean = K_trans.dot(self.alpha_)  # Line 4 (y_mean = f_star)
#     317             y_mean = self._y_train_mean + y_mean  # undo normal.
#
# /anaconda2/envs/spike_basico/lib/python3.6/site-packages/sklearn/gaussian_process/kernels.py in __call__(self, X, Y, eval_gradient)
#    1322                     "Gradient can only be evaluated when Y is None.")
#    1323             dists = cdist(X / length_scale, Y / length_scale,
# -> 1324                           metric='euclidean')
#    1325
#    1326         if self.nu == 0.5:
#
# /anaconda2/envs/spike_basico/lib/python3.6/site-packages/scipy/spatial/distance.py in cdist(XA, XB, metric, *args, **kwargs)
#    2600     out = kwargs.pop("out", None)
#    2601     if out is None:
# -> 2602         dm = np.empty((mA, mB), dtype=np.double)
#    2603     else:
#    2604         if out.shape != (mA, mB):
#
# KeyboardInterrupt:
